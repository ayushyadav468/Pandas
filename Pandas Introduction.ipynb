# %% [markdown]
# <h1>PANDAS</h1>

# %%
import pandas as pd

# %% [markdown]
# <h3>Creating, Reading and Writing Data Frame</h3>

# %% [markdown]
# <p>Creating by columns</p>

# %%
# Creating a data frame using pandas
# NOTE: Every list must have same length and each key must be different
a = pd.DataFrame({'Heading 1':[1,2,3,4], 'Heading 2':[5,6,7,8], 'Heading 3':[1,2.3,5.8,9], 'Heading 4':[0,0,0,0]})
print(a)
# Out:
#    Heading 1  Heading 2  Heading 3  Heading 4
# 0          1          5        1.0          0
# 1          2          6        2.3          0
# 2          3          7        5.8          0
# 3          4          8        9.0          0

# %% [markdown]
# <p>Creating by rows</p>

# %%
# The above data frame can also be created like this..
b = pd.DataFrame([[1,5,1.0,0],[2,6,2.3,0],[3,7,5.8,0],[4,8,9.0,0]],
                 columns=['Heading 1','Heading 2','Heading 3','Heading 4'])
print(b)
# Out:
#    Heading 1  Heading 2  Heading 3  Heading 4
# 0          1          5        1.0          0
# 1          2          6        2.3          0
# 2          3          7        5.8          0
# 3          4          8        9.0          0

# %%
# Using index attribute
a = pd.DataFrame({'Heading 1':[1,2,3,4], 'Heading 2':[5,6,7,8], 'Heading 3':[1,2.3,5.8,9], 'Heading 4':[0,0,0,0]},
                index=['Row 1', 'Row 2', 'Row 3', 'Row 4'])
print(a)
# Out:
#        Heading 1  Heading 2  Heading 3  Heading 4
# Row 1          1          5        1.0          0
# Row 2          2          6        2.3          0
# Row 3          3          7        5.8          0
# Row 4          4          8        9.0          0

# %%
# Series, it is similar to data frame but doesn't have
# more than one column and
# column heading
b = pd.Series([1,2,3,4], index=['row 1','row 2','row 3','row 4'], name='Example')
print(b)
# Out:
# row 1    1
# row 2    2
# row 3    3
# row 4    4
# Name: Example, dtype: int64

# %%
# Reading a csv(comma seperated file) file from local machine
data = pd.read_csv('/Users/ayushyadav/DataSets/winemag-data_first150k.csv', index_col=0)
# index_col attribute make the 0th column as index, rather than creating new index
data.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
print(data.shape) #to see how many entries the data set contains
# Out:
# (150930, 10)

# %%
# .describe shows mathematical information regarding data set
data.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
# To store a data frame
# data.to_csv('to_write_a_csv_file.csv')

# %% [markdown]
# <h3>Indexing, Selecting and Assigning</h3>

# %%
data
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
# To access to a column
# but this can only for a single word heading, not if the column name conatin a space
data.country
# or
data['country']
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
# Slicing of rows using column name
data['country'][:10]
# Out:
# 0        US
# 1     Spain
# 2        US
# 3        US
# 4    France
# 5     Spain
# 6     Spain
# 7     Spain
# 8        US
# 9        US
# Name: country, dtype: object

# %%
# Indexing by rows
# iloc(Integer location)
data.iloc[:10]
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 6   Spain  Slightly gritty black-fruit aromas include a s...
# 7   Spain  Lush cedary black-fruit aromas are luxe and of...
# 8      US  This re-named vineyard was formerly bottled as...
# 9      US  The producer sources from two blocks of the vi...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# ...

# %%
# for accessing selected rows and columns
# format .iloc[rows, columns]
data.iloc[:5,[0,2,3,4]]
# Out:
#   country                           designation  points  price
# 0      US                     Martha's Vineyard      96  235.0
# 1   Spain  Carodorum Selección Especial Reserva      96  110.0
# 2      US         Special Selected Late Harvest      96   90.0
# 3      US                               Reserve      96   65.0
# 4  France                            La Brûlade      95   66.0

# %%
# loc is used for accessing rows and columns by name, rather than their indexes/indices
# while iloc exclude the last integer while indexing,
# iterating from 0 to 5, 5 will not be included
# loc attribute include the last integer, i.e.
# iterating from 0 to 5, 5 will be included, thus making total of 6 rows
# format remains the same, .loc[row, columns]
data.loc[:5, ['country', 'designation', 'points', 'price']]
# Out:
#   country                           designation  points  price
# 0      US                     Martha's Vineyard      96  235.0
# 1   Spain  Carodorum Selección Especial Reserva      96  110.0
# 2      US         Special Selected Late Harvest      96   90.0
# 3      US                               Reserve      96   65.0
# 4  France                            La Brûlade      95   66.0
# 5   Spain                             Numanthia      95   73.0

# %% [markdown]
# <h3>Condition</h3>

# %%
data['country'] == 'US'
# data.country == 'US'
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: country, Length: 150930, dtype: bool

# %%
data.loc[data.country == 'US']
# data.loc[data['country'] == 'US']
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# ...        ...                                                ...
# 150892      US  A light, earthy wine, with violet, berry and t...
# 150896      US  Some raspberry fruit in the aroma, but things ...
# 150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      US  An impressive wine that presents a full bouque...
#
#                           designation  points  price    province  \
# 0                   Martha's Vineyard      96  235.0  California
# ...

# %%
# for multiple conditions
# use bit wise '&' rather than 'and'
# for or, use bitwise '|' rather than 'or'
print(data.loc[(data['country'] == 'France') & (data['points'] >= 90)])
print(data.loc[(data['country'] == 'France') | (data['points'] >= 90)])
# Out:
#        country                                        description  \
# 4       France  This is the top wine from La Bégude, named aft...
# 13      France  This wine is in peak condition. The tannins an...
# 18      France  Coming from a seven-acre vineyard named after ...
# 33      France  Pale in color, this is nutty in character, wit...
# 36      France  Gingery spice notes accent fresh pear and melo...
# ...        ...                                                ...
# 150921  France  Shows some older notes: a bouquet of toasted w...
# 150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 150924  France  Really fine for a low-acid vintage, there's an...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150928  France  A perfect salmon shade, with scents of peaches...
#
#                           designation  points  price          province  \
# 4                          La Brûlade      95   66.0          Provence
# ...

# %%
# .isin attribute
data.loc[data['country'].isin(['Spain', 'France'])]
# Out:
#        country                                        description  \
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 4       France  This is the top wine from La Bégude, named aft...
# 5        Spain  Deep, dense and pure from the opening bell, th...
# 6        Spain  Slightly gritty black-fruit aromas include a s...
# 7        Spain  Lush cedary black-fruit aromas are luxe and of...
# ...        ...                                                ...
# 150921  France  Shows some older notes: a bouquet of toasted w...
# 150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 150924  France  Really fine for a low-acid vintage, there's an...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150928  France  A perfect salmon shade, with scents of peaches...
#
#                                  designation  points  price        province  \
# 1       Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# ...

# %%
# notnull or isnull attribute
data.loc[data['price'].notnull()]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
data.loc[data['price'].isnull()]
# Out:
#             country                                        description  \
# 32            Italy  Underbrush, scorched earth, menthol and plum s...
# 56           France  Delicious while also young and textured, this ...
# 72            Italy  This offers aromas of red rose, wild berry, da...
# 82            Italy  Berry, baking spice, dried iris, mint and a hi...
# 116           Spain  Aromas of brandied cherry and crème de cassis ...
# ...             ...                                                ...
# 150377  New Zealand  Light and a bit herbal, like a pleasant St.-Jo...
# 150378  New Zealand  Impressive purple color, but less intense on t...
# 150587       Canada  Shows pronounced oily, earthy, almost tobacco-...
# 150673           US  Cherry-scented, clean and fruity. Good concent...
# 150922        Italy  Made by 30-ish Roberta Borghese high above Man...
#
#              designation  points  price            province  \
# ...
